# %%
# Data Extraction

import requests
import zipfile
import io
url = "https://github.com/PhonePe/pulse/archive/refs/heads/main.zip"
response = requests.get(url)
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_data:
    zip_data.extractall('phonepe transaction')
print('Data Extracted')
# Out:
# Data Extracted

# %%
# Importing Packages
import os
import json
import pandas as pd

# %% [markdown]
# # READING FILES FROM DIRECTORIES

# %%
path1="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/aggregated/transaction/country/india/state/"
agg_trans_list=os.listdir(path1)

# %%
column1 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_trans_list:
    curr_state = path1 + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_transaction = json.load(f)
                
                for i in ag_transaction["data"]["transactionData"]:
                    name=i["name"]
                    count=i["paymentInstruments"][0]["count"]
                    amount = i["paymentInstruments"][0]["amount"]
                    column1["Transaction_type"].append(name)
                    column1["Transaction_count"].append(count)
                    column1["Transaction_amount"].append(amount)
                    column1["states"].append(state)
                    column1["years"].append(year)
                    column1["Quarters"].append(int(file.strip(".json")))

# %%
agg_transaction=pd.DataFrame(column1)
agg_transaction["states"]=agg_transaction["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_transaction["states"]=agg_transaction["states"].str.replace("-"," ")
agg_transaction["states"]=agg_transaction["states"].str.title()
agg_transaction["states"]=agg_transaction["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
agg_transaction["states"].unique()
agg_transaction
# Out:
#                  states years  Quarters          Transaction_type  \
# 0     Andaman & Nicobar  2018         1  Recharge & bill payments
# 1     Andaman & Nicobar  2018         1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018         1         Merchant payments
# 3     Andaman & Nicobar  2018         1        Financial Services
# 4     Andaman & Nicobar  2018         1                    Others
# ...                 ...   ...       ...                       ...
# 5029        West Bengal  2024         4         Merchant payments
# 5030        West Bengal  2024         4     Peer-to-peer payments
# 5031        West Bengal  2024         4  Recharge & bill payments
# 5032        West Bengal  2024         4        Financial Services
# 5033        West Bengal  2024         4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# ...

# %%
path2="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/aggregated/insurance/country/india/state/"
agg_ins_list=os.listdir(path2)

# %%
column2 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_ins_list:
    curr_state = path2 + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_insurance = json.load(f)
                
                for i in ag_insurance["data"]["transactionData"]:
                    name=i["name"]
                    count=i["paymentInstruments"][0]["count"]
                    amount = i["paymentInstruments"][0]["amount"]
                    column2["Transaction_type"].append(name)
                    column2["Transaction_count"].append(count)
                    column2["Transaction_amount"].append(amount)
                    column2["states"].append(state)
                    column2["years"].append(year)
                    column2["Quarters"].append(int(file.strip(".json")))

# %%
agg_insurance=pd.DataFrame(column2)
agg_insurance["states"]=agg_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_insurance["states"]=agg_insurance["states"].str.replace("-"," ")
agg_insurance["states"]=agg_insurance["states"].str.title()
agg_insurance["states"]=agg_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
agg_insurance["states"].unique()
agg_insurance
# Out:
#                 states years  Quarters Transaction_type  Transaction_count  \
# 0    Andaman & Nicobar  2020         2        Insurance                  6
# 1    Andaman & Nicobar  2020         3        Insurance                 41
# 2    Andaman & Nicobar  2020         4        Insurance                124
# 3    Andaman & Nicobar  2021         1        Insurance                225
# 4    Andaman & Nicobar  2021         2        Insurance                137
# ..                 ...   ...       ...              ...                ...
# 677        West Bengal  2023         4        Insurance              72712
# 678        West Bengal  2024         1        Insurance              79576
# 679        West Bengal  2024         2        Insurance              67048
# 680        West Bengal  2024         3        Insurance              77158
# 681        West Bengal  2024         4        Insurance              91719
#
#      Transaction_amount
# 0                1360.0
# ...

# %%
path3="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/aggregated/user/country/india/state/"
agg_user_list=os.listdir(path3)

# %%
column3 = {"states":[], "years":[],"Quarters":[], "brands":[], "Transaction_count":[], "percentage":[]}
for state in agg_user_list:
    curr_state = path3 + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_user = json.load(f)
                try:
                    for i in ag_user["data"]["usersByDevice"]:
                        brand=i["brand"]
                        count=i["count"]
                        percentage = i["percentage"]
                        column3["brands"].append(brand)
                        column3["Transaction_count"].append(count)
                        column3["percentage"].append(percentage)
                        column3["states"].append(state)
                        column3["years"].append(year)
                        column3["Quarters"].append(int(file.strip(".json")))
                except:
                    pass

# %%
agg_users=pd.DataFrame(column3)
agg_users["states"]=agg_users["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
agg_users["states"]=agg_users["states"].str.replace("-"," ")
agg_users["states"]=agg_users["states"].str.title()
agg_users["states"]=agg_users["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
agg_users["states"].unique()
agg_users
# Out:
#                  states years  Quarters   brands  Transaction_count  \
# 0     Andaman & Nicobar  2018         1   Xiaomi               1665
# 1     Andaman & Nicobar  2018         1  Samsung               1445
# 2     Andaman & Nicobar  2018         1     Vivo                982
# 3     Andaman & Nicobar  2018         1     Oppo                501
# 4     Andaman & Nicobar  2018         1  OnePlus                332
# ...                 ...   ...       ...      ...                ...
# 6727        West Bengal  2022         1   Lenovo             330017
# 6728        West Bengal  2022         1  Infinix             284678
# 6729        West Bengal  2022         1     Asus             280347
# 6730        West Bengal  2022         1    Apple             277752
# 6731        West Bengal  2022         1   Others            2196334
#
#       percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# 3       0.074332
# 4       0.049258
# ...          ...
# 6727    0.015056
# ...

# %%
path4="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/map/insurance/hover/country/india/state/"
map_ins_list=os.listdir(path4)

# %%
column4 = {"states":[], "years":[],"Quarters":[], "districts":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_ins_list:
    curr_state = path4 + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_insurance = json.load(f)
                
                for i in mp_insurance["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount = i["metric"][0]["amount"]
                    column4["districts"].append(name)
                    column4["Transaction_count"].append(count)
                    column4["Transaction_amount"].append(amount)
                    column4["states"].append(state)
                    column4["years"].append(year)
                    column4["Quarters"].append(int(file.strip(".json")))

# %%
map_insurance=pd.DataFrame(column4)
map_insurance["states"]=map_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
map_insurance["states"]=map_insurance["states"].str.replace("-"," ")
map_insurance["states"]=map_insurance["states"].str.title()
map_insurance["states"]=map_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
map_insurance["states"].unique()
map_insurance
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2020         2             south andaman district
# 1      Andaman & Nicobar  2020         2                  nicobars district
# 2      Andaman & Nicobar  2020         3  north and middle andaman district
# 3      Andaman & Nicobar  2020         3             south andaman district
# 4      Andaman & Nicobar  2020         3                  nicobars district
# ...                  ...   ...       ...                                ...
# 13871        West Bengal  2024         4                alipurduar district
# 13872        West Bengal  2024         4         paschim bardhaman district
# 13873        West Bengal  2024         4                     nadia district
# 13874        West Bengal  2024         4                   birbhum district
# 13875        West Bengal  2024         4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
path5="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/map/transaction/hover/country/india/state/"
map_trans_list=os.listdir(path5)

# %%
column5 = {"states":[], "years":[],"Quarters":[], "districts":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_trans_list:
    curr_state = path5 + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_transaction = json.load(f)
                
                for i in mp_transaction["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount = i["metric"][0]["amount"]
                    column5["districts"].append(name)
                    column5["Transaction_count"].append(count)
                    column5["Transaction_amount"].append(amount)
                    column5["states"].append(state)
                    column5["years"].append(year)
                    column5["Quarters"].append(int(file.strip(".json")))

# %%
map_transaction=pd.DataFrame(column5)
map_transaction["states"]=map_transaction["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
map_transaction["states"]=map_transaction["states"].str.replace("-"," ")
map_transaction["states"]=map_transaction["states"].str.title()
map_transaction["states"]=map_transaction["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
map_transaction["states"].unique()
map_transaction
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2018         1  north and middle andaman district
# 1      Andaman & Nicobar  2018         1             south andaman district
# 2      Andaman & Nicobar  2018         1                  nicobars district
# 3      Andaman & Nicobar  2018         2  north and middle andaman district
# 4      Andaman & Nicobar  2018         2             south andaman district
# ...                  ...   ...       ...                                ...
# 20599        West Bengal  2024         4                alipurduar district
# 20600        West Bengal  2024         4         paschim bardhaman district
# 20601        West Bengal  2024         4                     nadia district
# 20602        West Bengal  2024         4                   birbhum district
# 20603        West Bengal  2024         4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
path6="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/map/user/hover/country/india/state/"
map_user_list=os.listdir(path6)

# %%
column6 = {"states": [], "years": [], "Quarters": [], "districts": [], "RegisteredUsers": [], "AppOpens": []}

for state in map_user_list:
    curr_state = path6 + state + "/"
    map_year_list = os.listdir(curr_state)

    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)

        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_user = json.load(f)
                for i in mp_user["data"]["hoverData"].items():
                     district=i[0]
                     registeredUsers=i[1]["registeredUsers"]
                     appOpens = i[1]["appOpens"]
                     column6["districts"].append(district)
                     column6["RegisteredUsers"].append(registeredUsers)
                     column6["AppOpens"].append(appOpens)
                     column6["states"].append(state)
                     column6["years"].append(year)
                     column6["Quarters"].append(int(file.strip(".json")))

# %%
map_users=pd.DataFrame(column6)
map_users["states"]=map_users["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
map_users["states"]=map_users["states"].str.replace("-"," ")
map_users["states"]=map_users["states"].str.title()
map_users["states"]=map_users["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
map_users["states"].unique()
map_users
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2018         1  north and middle andaman district
# 1      Andaman & Nicobar  2018         1             south andaman district
# 2      Andaman & Nicobar  2018         1                  nicobars district
# 3      Andaman & Nicobar  2018         2  north and middle andaman district
# 4      Andaman & Nicobar  2018         2             south andaman district
# ...                  ...   ...       ...                                ...
# 20603        West Bengal  2024         4                alipurduar district
# 20604        West Bengal  2024         4         paschim bardhaman district
# 20605        West Bengal  2024         4                     nadia district
# 20606        West Bengal  2024         4                   birbhum district
# 20607        West Bengal  2024         4           purba medinipur district
#
#        RegisteredUsers   AppOpens
# ...

# %%
path7="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/top/insurance/country/india/state/"
top_ins_list=os.listdir(path7)

# %%
column7 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "Transaction_count": [], "Transaction_amount": []}

for state in top_ins_list:
    curr_state = path7 + state + "/"
    top_year_list = os.listdir(curr_state)

    for year in top_year_list:
        curr_year = curr_state + year + "/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                top_ins = json.load(f)
                for i in top_ins["data"]["pincodes"]:
                     entityname=i["entityName"]
                     count=i["metric"]["count"]
                     amount = i["metric"]["amount"]
                     column7["Pincodes"].append(entityname)
                     column7["Transaction_count"].append(count)
                     column7["Transaction_amount"].append(amount)
                     column7["states"].append(state)
                     column7["years"].append(year)
                     column7["Quarters"].append(int(file.strip(".json")))

# %%
top_insurance=pd.DataFrame(column7)
top_insurance["states"]=top_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_insurance["states"]=top_insurance["states"].str.replace("-"," ")
top_insurance["states"]=top_insurance["states"].str.title()
top_insurance["states"]=top_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_insurance["states"].unique()
top_insurance
# Out:
#                  states years  Quarters Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2020         2   744301                  3
# 1     Andaman & Nicobar  2020         2   744104                  2
# 2     Andaman & Nicobar  2020         2   744101                  1
# 3     Andaman & Nicobar  2020         3   744112                  9
# 4     Andaman & Nicobar  2020         3   744105                  7
# ...                 ...   ...       ...      ...                ...
# 6663        West Bengal  2024         4   711101                713
# 6664        West Bengal  2024         4   700091                642
# 6665        West Bengal  2024         4   700150                627
# 6666        West Bengal  2024         4   700039                619
# 6667        West Bengal  2024         4   700156                574
#
#       Transaction_amount
# 0                  565.0
# 1                  513.0
# 2                  282.0
# 3                 3432.0
# ...

# %%
path8="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/top/transaction/country/india/state/"
top_trans_list=os.listdir(path8)

# %%
column8 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "Transaction_count": [], "Transaction_amount": []}

for file in top_file_list:
    if file.endswith(".json"):  # Only process JSON files
        curr_file = curr_year + file
        with open(curr_file, "r") as f:
            top_trans = json.load(f)
            for i in top_trans["data"]["pincodes"]:
                entityname = i["entityName"]
                count = i["metric"]["count"]
                amount = i["metric"]["amount"]
                column8["Pincodes"].append(entityname)
                column8["Transaction_count"].append(count)
                column8["Transaction_amount"].append(amount)
                column8["states"].append(state)
                column8["years"].append(year)
                column8["Quarters"].append(int(file.strip(".json")))

# %%
top_transaction=pd.DataFrame(column8)
top_transaction["states"]=top_transaction["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_transaction["states"]=top_transaction["states"].str.replace("-"," ")
top_transaction["states"]=top_transaction["states"].str.title()
top_transaction["states"]=top_transaction["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_transaction["states"].unique()
top_transaction
# Out:
#                states years  Quarters Pincodes  Transaction_count  \
# 0   Andaman & Nicobar  2018         1   744101               1622
# 1   Andaman & Nicobar  2018         1   744103               1223
# 2   Andaman & Nicobar  2018         1   744102                969
# 3   Andaman & Nicobar  2018         1   744105                685
# 4   Andaman & Nicobar  2018         1   744104                340
# 5   Andaman & Nicobar  2018         1   744107                302
# 6   Andaman & Nicobar  2018         1   744301                283
# 7   Andaman & Nicobar  2018         1   744112                269
# 8   Andaman & Nicobar  2018         1   744202                193
# 9   Andaman & Nicobar  2018         1   744302                168
# 10  Andaman & Nicobar  2018         2   744101               2701
# 11  Andaman & Nicobar  2018         2   744103               1965
# 12  Andaman & Nicobar  2018         2   744102               1525
# ...

# %%
path9="C:/Users/a/OneDrive/Desktop/pythonclass/phonepe transaction/pulse-master/data/top/user/country/india/state/"
top_user_list=os.listdir(path9)

# %%
column9 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "RegisteredUsers": []}

for state in top_user_list:
    curr_state = path9 + state + "/"
    top_year_list = os.listdir(curr_state)

    for year in top_year_list:
        curr_year = curr_state + year + "/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                top_user = json.load(f)
                for i in top_user["data"]["pincodes"]:
                     name=i["name"]
                     registeredusers=i["registeredUsers"]
                     column9["Pincodes"].append(name)
                     column9["RegisteredUsers"].append(registeredusers)
                     column9["states"].append(state)
                     column9["years"].append(year)
                     column9["Quarters"].append(int(file.strip(".json")))

# %%
top_users=pd.DataFrame(column9)
top_users["states"]=top_users["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_users["states"]=top_users["states"].str.replace("-"," ")
top_users["states"]=top_users["states"].str.title()
top_users["states"]=top_users["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_users["states"].unique()
top_users
# Out:
#                  states years  Quarters Pincodes  RegisteredUsers
# 0     Andaman & Nicobar  2018         1   744103             1608
# 1     Andaman & Nicobar  2018         1   744101             1108
# 2     Andaman & Nicobar  2018         1   744105             1075
# 3     Andaman & Nicobar  2018         1   744102             1006
# 4     Andaman & Nicobar  2018         1   744104              272
# ...                 ...   ...       ...      ...              ...
# 9995        West Bengal  2024         4   733134           169596
# 9996        West Bengal  2024         4   700059           169448
# 9997        West Bengal  2024         4   711302           146034
# 9998        West Bengal  2024         4   700150           142151
# 9999        West Bengal  2024         4   711106           142077
#
# [10000 rows x 5 columns]

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as db

# %%
# Connecting MYSQL with Python
user='Meenu'
host='localhost'
passcode='21Harsha$'
db_name='project2'

# %%
db_connection=db.connect(
    user=user,
    host=host,
    password=passcode,
    database=db_name
)

# %%
db_connection

# %%
curr=db_connection.cursor()

# %% [markdown]
# # CREATING TABLES AND INSERTING VALUES IN MYSQL

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS agg_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Transaction_type Varchar(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql=""" INSERT INTO project2.agg_insurance(States,Years,Quarter,Transaction_type,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data=agg_insurance.values.tolist()
curr.executemany(sql,data)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS agg_transaction (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Transaction_type Varchar(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql1=""" INSERT INTO project2.agg_transaction(States,Years,Quarter,Transaction_type,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data1=agg_transaction.values.tolist()
curr.executemany(sql1,data1)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS agg_users (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Brands VARCHAR(255),
        Transaction_count BIGINT,
        Percentage FLOAT
    
);
""")
db_connection.commit()

# %%
sql2=""" INSERT INTO project2.agg_users(States,Years,Quarter,Brands,Transaction_count,Percentage)
         values(%s,%s,%s,%s,%s,%s)"""
data2=agg_users.values.tolist()
curr.executemany(sql2,data2)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS map_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql3=""" INSERT INTO project2.map_insurance(States,Years,Quarter,District,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data3=map_insurance.values.tolist()
curr.executemany(sql3,data3)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS map_transaction (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql4=""" INSERT INTO project2.map_transaction(States,Years,Quarter,District,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data4=map_transaction.values.tolist()
curr.executemany(sql4,data4)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS map_users (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Registeredusers BIGINT,
        AppOpens BIGINT
    
);
""")
db_connection.commit()

# %%
sql5=""" INSERT INTO project2.map_users(States,Years,Quarter,District,Registeredusers,AppOpens)
         values(%s,%s,%s,%s,%s,%s)"""
data5=map_users.values.tolist()
curr.executemany(sql5,data5)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql6=""" INSERT INTO project2.top_insurance(States,Years,Quarter,Pincodes,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data6=top_insurance.values.tolist()
curr.executemany(sql6,data6)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_transaction (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
sql7=""" INSERT INTO project2.top_transaction(States,Years,Quarter,Pincodes,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
data7=top_transaction.values.tolist()
curr.executemany(sql7,data7)
db_connection.commit()

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_users (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Registeredusers BIGINT
    
);
""")
db_connection.commit()

# %%
sql8=""" INSERT INTO project2.top_users(States,Years,Quarter,Pincodes,Registeredusers)
         values(%s,%s,%s,%s,%s)"""
data8=top_users.values.tolist()
curr.executemany(sql8,data8)
db_connection.commit()

# %%
user='Meenu'
host='localhost'
passcode='21Harsha$'
db_name='project2'

# %%
db_connection=db.connect(
    user=user,
    host=host,
    password=passcode,
    database=db_name
)

# %%
curr.execute("SELECT * FROM agg_insurance")
db_connection.commit()
table1=curr.fetchall()
aggre_insurance=pd.DataFrame(table1,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
aggre_insurance
# Out:
#                  States  Years  Quarter Transaction_type  Transaction_count  \
# 0     Andaman & Nicobar   2020        2        Insurance                  6
# 1     Andaman & Nicobar   2020        3        Insurance                 41
# 2     Andaman & Nicobar   2020        4        Insurance                124
# 3     Andaman & Nicobar   2021        1        Insurance                225
# 4     Andaman & Nicobar   2021        2        Insurance                137
# ...                 ...    ...      ...              ...                ...
# 2723        West Bengal   2023        4        Insurance              72712
# 2724        West Bengal   2024        1        Insurance              79576
# 2725        West Bengal   2024        2        Insurance              67048
# 2726        West Bengal   2024        3        Insurance              77158
# 2727        West Bengal   2024        4        Insurance              91719
#
#       Transaction_amount
# 0                   1360
# ...

# %%
curr.execute("SELECT * FROM agg_transaction")
db_connection.commit()
table2=curr.fetchall()
aggre_transaction=pd.DataFrame(table2,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
aggre_transaction
# Out:
#                   States  Years  Quarter          Transaction_type  \
# 0      Andaman & Nicobar   2018        1  Recharge & bill payments
# 1      Andaman & Nicobar   2018        1     Peer-to-peer payments
# 2      Andaman & Nicobar   2018        1         Merchant payments
# 3      Andaman & Nicobar   2018        1        Financial Services
# 4      Andaman & Nicobar   2018        1                    Others
# ...                  ...    ...      ...                       ...
# 20131        West Bengal   2024        4         Merchant payments
# 20132        West Bengal   2024        4     Peer-to-peer payments
# 20133        West Bengal   2024        4  Recharge & bill payments
# 20134        West Bengal   2024        4        Financial Services
# 20135        West Bengal   2024        4                    Others
#
#        Transaction_count  Transaction_amount
# 0                   4200             1845307
# 1                   1871            12138655
# ...

# %%
curr.execute("SELECT * FROM agg_users")
db_connection.commit()
table3=curr.fetchall()
aggre_users=pd.DataFrame(table3,columns=("States","Years","Quarter","Brands","Transaction_count","Percentage"))

# %%
aggre_users
# Out:
#                   States  Years  Quarter   Brands  Transaction_count  \
# 0      Andaman & Nicobar   2018        1   Xiaomi               1665
# 1      Andaman & Nicobar   2018        1  Samsung               1445
# 2      Andaman & Nicobar   2018        1     Vivo                982
# 3      Andaman & Nicobar   2018        1     Oppo                501
# 4      Andaman & Nicobar   2018        1  OnePlus                332
# ...                  ...    ...      ...      ...                ...
# 26923        West Bengal   2022        1   Lenovo             330017
# 26924        West Bengal   2022        1  Infinix             284678
# 26925        West Bengal   2022        1     Asus             280347
# 26926        West Bengal   2022        1    Apple             277752
# 26927        West Bengal   2022        1   Others            2196334
#
#        Percentage
# 0        0.247033
# 1        0.214392
# 2        0.145697
# 3        0.074332
# 4        0.049258
# ...           ...
# ...

# %%
curr.execute("SELECT * FROM Map_insurance")
db_connection.commit()
table4=curr.fetchall()
map_ins=pd.DataFrame(table4,columns=("States","Years","Quarter","District","Transaction_count","Transaction_amount"))

# %%
map_ins
# Out:
#                   States  Years  Quarter                           District  \
# 0      Andaman & Nicobar   2020        2             south andaman district
# 1      Andaman & Nicobar   2020        2                  nicobars district
# 2      Andaman & Nicobar   2020        3  north and middle andaman district
# 3      Andaman & Nicobar   2020        3             south andaman district
# 4      Andaman & Nicobar   2020        3                  nicobars district
# ...                  ...    ...      ...                                ...
# 69375        West Bengal   2024        4                alipurduar district
# 69376        West Bengal   2024        4         paschim bardhaman district
# 69377        West Bengal   2024        4                     nadia district
# 69378        West Bengal   2024        4                   birbhum district
# 69379        West Bengal   2024        4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
curr.execute("SELECT * FROM Map_transaction")
db_connection.commit()
table5=curr.fetchall()
map_trans=pd.DataFrame(table5,columns=("States","Years","Quarter","District","Transaction_count","Transaction_amount"))

# %%
map_trans
# Out:
#                    States  Years  Quarter                           District  \
# 0       Andaman & Nicobar   2018        1  north and middle andaman district
# 1       Andaman & Nicobar   2018        1             south andaman district
# 2       Andaman & Nicobar   2018        1                  nicobars district
# 3       Andaman & Nicobar   2018        2  north and middle andaman district
# 4       Andaman & Nicobar   2018        2             south andaman district
# ...                   ...    ...      ...                                ...
# 123619        West Bengal   2024        4                alipurduar district
# 123620        West Bengal   2024        4         paschim bardhaman district
# 123621        West Bengal   2024        4                     nadia district
# 123622        West Bengal   2024        4                   birbhum district
# 123623        West Bengal   2024        4           purba medinipur district
#
# ...

# %%
curr.execute("SELECT * FROM Map_users")
db_connection.commit()
table6=curr.fetchall()
map_users=pd.DataFrame(table6,columns=("States","Years","Quarter","District","Registeredusers","AppOpens"))

# %%
map_users
# Out:
#                    States  Years  Quarter                           District  \
# 0       Andaman & Nicobar   2018        1  north and middle andaman district
# 1       Andaman & Nicobar   2018        1             south andaman district
# 2       Andaman & Nicobar   2018        1                  nicobars district
# 3       Andaman & Nicobar   2018        2  north and middle andaman district
# 4       Andaman & Nicobar   2018        2             south andaman district
# ...                   ...    ...      ...                                ...
# 103035        West Bengal   2024        4                alipurduar district
# 103036        West Bengal   2024        4         paschim bardhaman district
# 103037        West Bengal   2024        4                     nadia district
# 103038        West Bengal   2024        4                   birbhum district
# 103039        West Bengal   2024        4           purba medinipur district
#
#         Registeredusers   AppOpens
# ...

# %%
curr.execute("SELECT * FROM top_insurance")
db_connection.commit()
table7=curr.fetchall()
top_ins=pd.DataFrame(table7,columns=("States","Years","Quarter","Pincodes","Transaction_count","Transaction_amount"))

# %%
top_ins
# Out:
#                   States  Years  Quarter  Pincodes  Transaction_count  \
# 0      Andaman & Nicobar   2020        2  744301.0                  3
# 1      Andaman & Nicobar   2020        2  744104.0                  2
# 2      Andaman & Nicobar   2020        2  744101.0                  1
# 3      Andaman & Nicobar   2020        3  744112.0                  9
# 4      Andaman & Nicobar   2020        3  744105.0                  7
# ...                  ...    ...      ...       ...                ...
# 33335        West Bengal   2024        4  711101.0                713
# 33336        West Bengal   2024        4  700091.0                642
# 33337        West Bengal   2024        4  700150.0                627
# 33338        West Bengal   2024        4  700039.0                619
# 33339        West Bengal   2024        4  700156.0                574
#
#        Transaction_amount
# 0                     565
# 1                     513
# 2                     282
# ...

# %%
curr.execute("SELECT * FROM top_transaction")
db_connection.commit()
table8=curr.fetchall()
top_trans=pd.DataFrame(table8,columns=("States","Years","Quarter","Pincodes","Transaction_count","Transaction_amount"))

# %%
top_trans
# Out:
#                   States  Years  Quarter  Pincodes  Transaction_count  \
# 0      Andaman & Nicobar   2018        1  744101.0               1622
# 1      Andaman & Nicobar   2018        1  744103.0               1223
# 2      Andaman & Nicobar   2018        1  744102.0                969
# 3      Andaman & Nicobar   2018        1  744105.0                685
# 4      Andaman & Nicobar   2018        1  744104.0                340
# ...                  ...    ...      ...       ...                ...
# 10154  Andaman & Nicobar   2018        4  744211.0               1225
# 10155  Andaman & Nicobar   2018        4  744301.0                928
# 10156  Andaman & Nicobar   2018        4  744112.0                759
# 10157  Andaman & Nicobar   2018        4  744107.0                747
# 10158  Andaman & Nicobar   2018        4  744202.0                702
#
#        Transaction_amount
# 0                 2769298
# 1                 2238042
# 2                 3519060
# ...

# %%
curr.execute("SELECT * FROM top_users")
db_connection.commit()
table9=curr.fetchall()
top_users=pd.DataFrame(table9,columns=("States","Years","Quarter","Pincodes","Registeredusers"))

# %%
top_users
# Out:
#                   States  Years  Quarter  Pincodes  Registeredusers
# 0      Andaman & Nicobar   2018        1    744103             1608
# 1      Andaman & Nicobar   2018        1    744101             1108
# 2      Andaman & Nicobar   2018        1    744105             1075
# 3      Andaman & Nicobar   2018        1    744102             1006
# 4      Andaman & Nicobar   2018        1    744104              272
# ...                  ...    ...      ...       ...              ...
# 39995        West Bengal   2024        4    733134           169596
# 39996        West Bengal   2024        4    700059           169448
# 39997        West Bengal   2024        4    711302           146034
# 39998        West Bengal   2024        4    700150           142151
# 39999        West Bengal   2024        4    711106           142077
#
# [40000 rows x 5 columns]

# %%
curr.execute("""

CREATE TABLE IF NOT EXISTS geo_state (
    state VARCHAR(100),
    lat FLOAT,
    lon FLOAT
);
""")
db_connection.commit()

# %%
geo_data = [
    ('Andhra Pradesh', 15.9129, 79.7400),
    ('Arunachal Pradesh', 28.2180, 94.7278),
    ('Assam', 26.2006, 92.9376),
    ('Bihar', 25.0961, 85.3131),
    ('Chhattisgarh', 21.2787, 81.8661),
    ('Goa', 15.2993, 74.1240),
    ('Gujarat', 22.2587, 71.1924),
    ('Haryana', 29.0588, 76.0856),
    ('Himachal Pradesh', 31.1048, 77.1734),
    ('Jharkhand', 23.6102, 85.2799),
    ('Karnataka', 15.3173, 75.7139),
    ('Kerala', 10.8505, 76.2711),
    ('Madhya Pradesh', 22.9734, 78.6569),
    ('Maharashtra', 19.7515, 75.7139),
    ('Manipur', 24.6637, 93.9063),
    ('Meghalaya', 25.4670, 91.3662),
    ('Mizoram', 23.1645, 92.9376),
    ('Nagaland', 26.1584, 94.5624),
    ('Odisha', 20.9517, 85.0985),
    ('Punjab', 31.1471, 75.3412),
    ('Rajasthan', 27.0238, 74.2179),
    ('Sikkim', 27.5330, 88.5122),
    ('Tamil Nadu', 11.1271, 78.6569),
    ('Telangana', 18.1124, 79.0193),
    ('Tripura', 23.9408, 91.9882),
    ('Uttar Pradesh', 26.8467, 80.9462),
    ('Uttarakhand', 30.0668, 79.0193),
    ('West Bengal', 22.9868, 87.8550)
]

insert_query = """INSERT INTO geo_state (state, lat, lon) VALUES (%s, %s, %s)"""
curr.executemany(insert_query, geo_data)
db_connection.commit()
